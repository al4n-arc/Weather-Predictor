# %%
import pandas as pd
import pickle
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv(r"E:\Akira\Project!!\Csv Fin\Final!!.csv")
data
# Out:
#      PARAMETERS   SO2    CO    NO    NO2    NOX   NH3     O3  AQI    WS  \
# 0    01/01/2023  2.02  0.06  8.93  17.84  26.00  8.93  26.07   72  0.33
# 1    02/01/2023  1.63  0.12  8.89  17.74  26.00  8.89  25.97   81  0.47
# 2    03/01/2023  3.46  0.03  8.91  17.89  26.00  8.91  26.03   82  0.19
# 3    04/01/2023  2.79  0.11  8.88  17.77  26.00  8.88  25.95   79  0.54
# 4    05/01/2023  1.15  0.22  9.48  17.73  26.00  9.48  23.93   84  0.43
# ..          ...   ...   ...   ...    ...    ...   ...    ...  ...   ...
# 670  12/27/2024  3.53  0.53  1.45   5.34   6.68  1.45  36.20   66  0.80
# 671  12/28/2024  3.65  0.48  1.44   5.35   6.72  1.44  36.17   64  0.82
# 672  12/29/2024  4.64  0.49  1.42   5.35   6.58  1.42  36.21   60  0.82
# 673  12/30/2024  4.18  0.53  1.44   5.37   6.77  1.44  36.20   60  0.70
# 674  12/31/2024  3.67  0.62  1.42   5.35   6.61  1.42  36.19   60  0.72
#
#          WD     RH      SR     TC
# 0     37.96  80.27  199.80  28.70
# ...

# %%
data.shape
# Out:
# (675, 14)

# %%
data.head()
# Out:
#    PARAMETERS   SO2    CO    NO    NO2   NOX   NH3     O3  AQI    WS     WD  \
# 0  01/01/2023  2.02  0.06  8.93  17.84  26.0  8.93  26.07   72  0.33  37.96
# 1  02/01/2023  1.63  0.12  8.89  17.74  26.0  8.89  25.97   81  0.47  33.84
# 2  03/01/2023  3.46  0.03  8.91  17.89  26.0  8.91  26.03   82  0.19  54.37
# 3  04/01/2023  2.79  0.11  8.88  17.77  26.0  8.88  25.95   79  0.54  40.44
# 4  05/01/2023  1.15  0.22  9.48  17.73  26.0  9.48  23.93   84  0.43  42.53
#
#       RH     SR     TC
# 0  80.27  199.8  28.70
# 1  82.50  189.1  28.11
# 2  71.00  203.1  28.55
# 3  78.11  205.2  28.25
# 4  78.56  202.3  28.55

# %%
data.isnull().sum()
# Out:
# PARAMETERS    0
# SO2           0
# CO            0
# NO            0
# NO2           0
# NOX           0
# NH3           0
# O3            0
# AQI           0
# WS            0
# WD            0
# RH            0
# SR            1
# TC            0
# dtype: int64

# %%
data_cleaned=data.dropna(inplace=True)

# %%
x=data[['SO2','CO','NO','NO2','TC','NH3','O3','WS','WD','RH','SR','TC']]
y=data['AQI']

# %% [markdown]
# KNN REGRESSOR!!

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (539, 12)

# %%
x_test.shape
# Out:
# (135, 12)

# %%
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor(n_neighbors=3)
model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score      #Accuracy!!!
r2_score(y_test,y_pred)
# Out:
# 0.6969499058258389

# %% [markdown]
# DECISON TREE!!!

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
reg2=DecisionTreeRegressor()
reg2.fit(x_train,y_train)
y_pred=reg2.predict(x_test)
print(y_pred)
print(r2_score(y_test,y_pred))
# Out:
# [ 64.  50.  41.  38.  44.  52.  64.  71.  88.  99.  88.  86.  45.  44.
#   89.  70.  66.  61.  50.  38.  65.  60.  78.  75.  47.  41.  60.  87.
#   55.  85.  83.  38.  31.  40.  60.  88.  42.  39.  58.  70.  35.  98.
#   70.  57.  71.  57.  46.  75.  84.  37.  48.  53.  46.  46.  75.  63.
#   47.  31.  86.  43.  82.  51.  83.  82.  40.  85.  38.  86. 107.  47.
#   70.  38.  85.  58.  70.  86.  41.  85.  87.  60.  58.  98.  86.  66.
#   41.  72.  81.  62.  63.  47.  38.  70.  53.  62.  64.  31.  85.  50.
#   86.  66.  57.  98.  37.  64.  61.  38.  59.  84.  89.  86.  42.  42.
#   55.  56.  97.  40.  83.  83.  79.  55.  64.  60.  44.  93.  41.  44.
#   89.  46.  58.  98.  38.  42.  67.  47.  43.]
# 0.671357212385927

# %% [markdown]
# RANDOM FOREST"

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
reg3=RandomForestRegressor(n_estimators=100)
reg3.fit(x_train,y_train)
y_pred=reg3.predict(x_test)
print(y_pred)
print(r2_score(y_test,y_pred))
# Out:
# [58.4  54.69 41.47 38.8  46.62 52.92 61.19 58.87 88.49 85.42 86.81 93.23
#  56.79 65.26 89.34 60.66 60.67 59.87 76.4  40.23 62.78 60.18 85.41 70.34
#  65.88 58.24 60.09 89.75 64.35 88.35 70.69 43.88 40.13 41.41 62.5  97.34
#  43.83 37.86 60.91 62.92 42.6  89.15 63.03 58.21 58.23 60.1  38.08 68.71
#  83.8  39.17 45.7  54.85 54.49 53.33 69.66 63.69 51.63 46.28 88.87 41.94
#  81.2  56.09 81.87 68.05 39.21 84.57 38.64 90.08 95.66 39.87 48.19 43.98
#  82.23 58.48 71.04 91.83 41.33 90.11 91.77 57.31 54.87 84.05 90.25 60.32
#  43.66 74.73 78.59 61.79 61.61 42.61 40.26 63.47 55.67 63.25 57.51 36.79
#  88.11 54.97 88.74 61.33 57.99 90.2  38.19 61.18 59.1  39.73 60.78 83.58
#  84.65 87.38 39.56 50.07 56.08 58.32 86.23 42.74 82.24 71.86 81.29 61.31
#  61.52 45.28 40.06 83.61 56.83 56.46 88.44 49.71 60.92 89.99 40.23 44.43
#  59.37 46.59 42.47]
# 0.8617188941052424

# %% [markdown]
# Highest Score In To A File!!

# %%
import pickle
with open('ModelRegr.pkl','wb') as file:
    pickle.dump(reg3,file)
